# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read csv file
df = pd.read_csv('/content/fitness_tracker.csv')
df.head()
# Out:
#    User_ID  Steps  Calories_Burned  Active_Minutes
# 0        1   9823              522             136
# 1        2   3745              443             137
# 2        3   1344              430             111
# 3        4  19918              645             177
# 4        5   5404              404              30

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled.head()
# Out:
#     User_ID     Steps  Calories_Burned  Active_Minutes
# 0  0.000000  0.462323         0.468820        0.745562
# 1  0.002004  0.141144         0.380846        0.751479
# 2  0.004008  0.014268         0.366370        0.597633
# 3  0.006012  0.995773         0.605791        0.988166
# 4  0.008016  0.228810         0.337416        0.118343

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled.head()
# Out:
#     User_ID     Steps  Calories_Burned  Active_Minutes
# 0 -1.728590 -0.108550        -0.140620        0.894620
# 1 -1.721662 -1.220194        -0.447922        0.914459
# 2 -1.714734 -1.659329        -0.498491        0.398645
# 3 -1.707806  1.737789         0.337838        1.708019
# 4 -1.700877 -0.916769        -0.599628       -1.208314

# %%
#find max calories burned
df_scaled['Calories_Burned'].max()
# Out:
# 1.7148621452835706

# %%
df_scaled['Calories_Burned'].min()
# Out:
# -1.7782675053110677

# %%
#mean
df_scaled['Calories_Burned'].mean()
# Out:
# np.float64(7.105427357601002e-17)

# %%
#most active person
max_calories_idx = df_scaled['Calories_Burned'].idxmax()
user_id_most_active = df.loc[max_calories_idx, 'User_ID']
print(f"The User ID with the most calories burned is: {user_id_most_active}")
# Out:
# The User ID with the most calories burned is: 244

# %%
#most lazy person
min_calories_idx = df_scaled['Calories_Burned'].idxmin()
user_id_most_lazy = df.loc[min_calories_idx, 'User_ID']
print(f"The User ID with the most calories burned is: {user_id_most_lazy}")
# Out:
# The User ID with the most calories burned is: 54

# %%
#standard devation
df_scaled['Calories_Burned'].std()
# Out:
# 1.0010015025043826

# %%
#variance
df_scaled['Calories_Burned'].var()
# Out:
# 1.0020040080160315

# %%
#line plot
df_scaled['Calories_Burned'].plot(kind='line')
plt.show()

# %%
plt.scatter(df_scaled['Calories_Burned'], df_scaled['Steps'])
plt.show()
